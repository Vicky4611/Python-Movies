# %%
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

pd.options.mode.chained_assignment = None



# Now we need to read in the data
df = pd.read_csv(r'C:\Users\USER\Downloads\movies.csv')
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
# We need to see if we have any missing data

for col in df.columns:
    print(df[col].isnull().value_counts(), "\n")
# Out:
# False    7668
# Name: name, dtype: int64
#
# False    7591
# True       77
# Name: rating, dtype: int64
#
# False    7668
# Name: genre, dtype: int64
#
# False    7668
# Name: year, dtype: int64
#
# False    7666
# True        2
# Name: released, dtype: int64
#
# False    7665
# True        3
# Name: score, dtype: int64
#
# False    7665
# True        3
# Name: votes, dtype: int64
#
# False    7668
# Name: director, dtype: int64
#
# False    7665
# True        3
# Name: writer, dtype: int64
#
# False    7667
# True        1
# Name: star, dtype: int64
#
# False    7665
# True        3
# Name: country, dtype: int64
#
# False    5497
# True     2171
# Name: budget, dtype: int64
#
# False    7479
# True      189
# Name: gross, dtype: int64
#
# False    7651
# True       17
# Name: company, dtype: int64
#
# False    7664
# True        4
# Name: runtime, dtype: int64

# %%
# Data Types for our columns

df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
# Change data type of columns to remove the decimal points

df['budget'] = pd.to_numeric(df['budget'], errors='coerce').fillna(0).astype(int)
df['gross'] = pd.to_numeric(df['gross'], errors='coerce').fillna(0).astype(int)
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country    budget  \
# ...

# %%
# Create correct year column

df['yearcorrect'] = df['released'].astype(str).str.split().str[2]
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country    budget  \
# ...

# %%
# Sorting the data by gross value

df = df.sort_values(by=['gross'], inplace=False, ascending=False)

# %%
# Viewing the entire dataset

pd.set_option('display.max_rows', None)

# %%
# Dropping the duplicates

df.drop_duplicates()
df.head()
# Out:
#    name  rating  genre  year  released  score      votes  director  writer  \
# 0  6587       6      6  1980      1705    8.4   927000.0      2589    4014
# 1  5573       6      1  1980      1492    5.8    65000.0      2269    1632
# 2  5142       4      0  1980      1771    8.7  1200000.0      1111    2567
# 3   286       4      4  1980      1492    7.7   221000.0      1301    2000
# 4  1027       6      4  1980      1543    7.3   108000.0      1054     521
#
#    star  country    budget      gross  company  runtime  yearcorrect
# 0  1047       54  19000000   46998772     2319    146.0            2
# 1   327       55   4500000   58853106      731    104.0            2
# 2  1745       55  18000000  538375067     1540    124.0            2
# 3  2246       55   3500000   83453539     1812     88.0            2
# 4   410       55   6000000   39846344     1777     98.0            2

# %%
# Budget high correlation
# Production company high correlation

# %%
# Scatter plot with budget vs gross

plt.scatter(x=df['gross'], y=df['budget'])
plt.title('Budget vs Gross Earnings')
plt.xlabel('Gross Earnings')
plt.ylabel('Budget for Film')

# Set limits for x and y axes to start from zero
plt.xlim(0, None)
plt.ylim(0, None)

plt.show()

# %%
df.head()
# Out:
#                                             name rating      genre  year  \
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13     Action  2015
# 7244                      Avengers: Infinity War  PG-13     Action  2018
# 7480                               The Lion King     PG  Animation  2019
# 6653                              Jurassic World  PG-13     Action  2015
# 6043                                The Avengers  PG-13     Action  2012
#
#                                released  score      votes         director  \
# 6663  December 18, 2015 (United States)    7.8   876000.0      J.J. Abrams
# 7244     April 27, 2018 (United States)    8.4   897000.0    Anthony Russo
# 7480      July 19, 2019 (United States)    6.9   222000.0      Jon Favreau
# 6653      June 12, 2015 (United States)    7.0   593000.0  Colin Trevorrow
# 6043        May 4, 2012 (United States)    8.0  1300000.0      Joss Whedon
#
#                   writer               star        country     budget  \
# ...

# %%
# Plotting budget vs gross using seaborn

sns.regplot(x="gross", y="budget", data=df, scatter_kws={"color": "black"}, line_kws={"color": "purple"})
plt.title('Budget vs Gross Earnings')
plt.xlabel('Gross Earnings')
plt.ylabel('Budget for Film')
plt.xlim(0, None)
plt.ylim(0, None)
plt.show()

# %%
# Looking at correlation

# %%
df.corr(method='pearson', numeric_only=True)
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.097995  0.222945  0.309212  0.256331  0.120811
# score    0.097995  1.000000  0.409182  0.055665  0.169406  0.399451
# votes    0.222945  0.409182  1.000000  0.486862  0.573889  0.309212
# budget   0.309212  0.055665  0.486862  1.000000  0.687124  0.269510
# gross    0.256331  0.169406  0.573889  0.687124  1.000000  0.204177
# runtime  0.120811  0.399451  0.309212  0.269510  0.204177  1.000000

# %%
# High correlation between budget and gross

# %%
correlation_matrix  = df.corr(method='pearson', numeric_only=True)
sns.heatmap(correlation_matrix, annot=True)
plt.title('Correlation matrix for Numeric features')
plt.xlabel('Movie features')
plt.ylabel('Movie features')
plt.show()

# %%
# Numerizing columns

# %%
df_numer = df

for col_name in df_numer.columns:
    if(df_numer[col_name].dtype == 'object'):
        df_numer[col_name]= df_numer[col_name].astype('category')
        df_numer[col_name] = df_numer[col_name].cat.codes
        
df_numer.head()
# Out:
#    name  rating  genre  year  released  score      votes  director  writer  \
# 0  6587       6      6  1980      1705    8.4   927000.0      2589    4014
# 1  5573       6      1  1980      1492    5.8    65000.0      2269    1632
# 2  5142       4      0  1980      1771    8.7  1200000.0      1111    2567
# 3   286       4      4  1980      1492    7.7   221000.0      1301    2000
# 4  1027       6      4  1980      1543    7.3   108000.0      1054     521
#
#    star  country    budget      gross  company  runtime  yearcorrect
# 0  1047       54  19000000   46998772     2319    146.0            2
# 1   327       55   4500000   58853106      731    104.0            2
# 2  1745       55  18000000  538375067     1540    124.0            2
# 3  2246       55   3500000   83453539     1812     88.0            2
# 4   410       55   6000000   39846344     1777     98.0            2

# %%
df.head()
# Out:
#    name  rating  genre  year  released  score      votes  director  writer  \
# 0  6587       6      6  1980      1705    8.4   927000.0      2589    4014
# 1  5573       6      1  1980      1492    5.8    65000.0      2269    1632
# 2  5142       4      0  1980      1771    8.7  1200000.0      1111    2567
# 3   286       4      4  1980      1492    7.7   221000.0      1301    2000
# 4  1027       6      4  1980      1543    7.3   108000.0      1054     521
#
#    star  country    budget      gross  company  runtime  yearcorrect
# 0  1047       54  19000000   46998772     2319    146.0            2
# 1   327       55   4500000   58853106      731    104.0            2
# 2  1745       55  18000000  538375067     1540    124.0            2
# 3  2246       55   3500000   83453539     1812     88.0            2
# 4   410       55   6000000   39846344     1777     98.0            2

# %%
correlation_matrix  = df_numer.corr(method='pearson', numeric_only=True)
sns.heatmap(correlation_matrix, annot=True)
plt.title('Correlation matrix for Numeric features')
plt.xlabel('Movie features')
plt.ylabel('Movie features')
plt.show()

# %%
# Correlation matrix of all the columns in numeric

df_numer.corr()
# Out:
#                  name    rating     genre      year  released     score  \
# name         1.000000 -0.008069  0.016355  0.011453 -0.011311  0.017097
# rating      -0.008069  1.000000  0.072423  0.008779  0.016613 -0.001314
# genre        0.016355  0.072423  1.000000 -0.081261  0.029822  0.027965
# year         0.011453  0.008779 -0.081261  1.000000 -0.000695  0.097995
# released    -0.011311  0.016613  0.029822 -0.000695  1.000000  0.042788
# score        0.017097 -0.001314  0.027965  0.097995  0.042788  1.000000
# votes        0.013088  0.033225 -0.145307  0.222945  0.016097  0.409182
# director     0.009079  0.019483 -0.015258 -0.020795 -0.001478  0.009559
# writer       0.009081 -0.005921  0.006567 -0.008656 -0.002404  0.019416
# star         0.006472  0.013405 -0.005477 -0.027242  0.015777 -0.001609
# country     -0.010737  0.081244 -0.037615 -0.070938 -0.020427 -0.133348
# budget       0.020548 -0.081939 -0.334021  0.309212  0.009145  0.055665
# ...

# %%
# Pairing correlation matrix

correlation_mat = df_numer.corr()
corr_pairs = correlation_mat.unstack()
corr_pairs.head()
# Out:
# name  name        1.000000
#       rating     -0.008069
#       genre       0.016355
#       year        0.011453
#       released   -0.011311
# dtype: float64

# %%
# Sorting correlation matrix

sorted_pairs = corr_pairs.sort_values()
sorted_pairs.head()
# Out:
# budget  genre    -0.334021
# genre   budget   -0.334021
# gross   genre    -0.229534
# genre   gross    -0.229534
#         votes    -0.145307
# dtype: float64

# %%
# High correlation

high_corr = sorted_pairs[(sorted_pairs) > 0.5]
high_corr
# Out:
# gross        votes          0.573889
# votes        gross          0.573889
# budget       gross          0.687124
# gross        budget         0.687124
# year         yearcorrect    0.990063
# yearcorrect  year           0.990063
# name         name           1.000000
# company      company        1.000000
# gross        gross          1.000000
# budget       budget         1.000000
# country      country        1.000000
# star         star           1.000000
# writer       writer         1.000000
# director     director       1.000000
# votes        votes          1.000000
# score        score          1.000000
# released     released       1.000000
# year         year           1.000000
# genre        genre          1.000000
# rating       rating         1.000000
# runtime      runtime        1.000000
# yearcorrect  yearcorrect    1.000000
# dtype: float64

# %% [markdown]
# #ANALYSIS OF MOVIES DATA
#
# #OVERVIEW
# In this analysis, we explore the correlation between gross earnings and other data to identify trends and patterns.
#
# #INSIGHTS
# Votes and budget exhibit the strongest correlation with gross earnings, indicating that movies with higher budgets tend to earn more at the box office, and movies with more votes tend to perform better financially. Conversely, the company shows a weaker correlation with gross earnings, suggesting that the production company behind a movie may have less impact on its financial success.
